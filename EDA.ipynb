# %%
'''
Types of data
Numerica 
    - Continous - 
    - Discrete
Categorical
    - 
EDA
    Univariate - 
        Categorical
            Count plot
                sns.countplot
                df.value_counts.plot(kind= 'bar')
            Piechart -
        Continous
            histogram
                import matplotlib.pyplot as plt
                plt.hist(<data>,bins =)
            distplot
                improvement on histogram
                sns.distplot() - pde (kde)
            boxplot 
                5 number summary
                sns.boxplot()
            df.skew()
    bivariate /    multivariate - 
        scatterplot -> num - num 
            - sns.scatterplot(,hue,style)
        barplot - > num - cat
            - sns.barplot(data1,data2,hue)
        boxplot - > num - cat
            - sns.boxplot(data1,data2,hue)
        distplot (num - cat)
            - sns.distplot(data1,hist=False)
            - sns.distplot(data2,hist=False)
        heatmap -> cat - cat
            - pd.crosstab(data,data)
            - sns.heatmap(crosstab_data)
        clustermap - > cat - cat
            pd.crosstab(data1,data2)
            clustermap() - closeness between the values
            dendograms
        pairplot - > collection of scatt
            numericals
            sns.pairplot(,hue = '')
        lineplot - > num -  num (time series)
            sns.lineplot()
    

Statisctics
    1. decriptive vs inferential
    2. population vs sample
    3. Sampling techniques

Types of data
    - numerical
        continous
        discrete
    - cat
        - norminal
        - ordinal
    
Descriptive statistics
    - measure of central tendancy
        - mean
        median
        mode
    - measure of spread
        range
        
        percentiles - np.percentile less than the value
        quartiles
        interquartile range - Q3 - Q1

        MAD - mean absolute deviation
            1/n sum1-n(Xi - Xbar)
        variance
            how far the data is spread across the mean
            1/n
            np.var
        standard deviation
            std dev = rootover(variance)
            np.std
        Median absolute deviation
            similar to mad
            When it is used?
            from statsmodel import robust
            robust.mad(np.array[])
            
        MAD vs variance
            smooth function
        
    - pdf
    - cdf
    - normal dist
    - z-score and z-table
    -  central limit theorem
Inferential statistics
    - hypothesis testing 
    

    
'''

# %%
# error idea
#module not found error -  probably issue with the package you are importing
    # what to do?
    #     check the spelling
    #     check if it is 3rd party package - if yes - install using pip install

# %%
import pandas as pd

# %%
titanic_df = pd.read_csv('Titanic-Dataset.csv')

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
pd.reas_csv('./data/Titanic-Dataset.csv')

# %%
titanic_df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
import seaborn as sns

# %%
sns.

# %%
titanic_df['Survived'].value_counts().plot(kind= 'bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
sns.countplot(x = 'Survived', data = titanic_df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x = 'Pclass', data = titanic_df)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
# univariate analysis
# definition  - when we are analyzing a single variable it is called as univariate analysis
# We start with the target variable/ dependeent variable and go for other variables of interest
sns.countplot(x = 'Survived', data = titanic_df)

# %%
sns.piechart(df['Survived'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 sns.piechart(df['Survived'])
#
# AttributeError: module 'seaborn' has no attribute 'piechart'

# %%
import matplotlib.pyplot as plt
plt.hist(titanic_df['Age'],bins = 10)
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
distplot
                improvement on histogram
                sns.distplot() - pde (kde)
            boxplot 
                5 number summary
                sns.boxplot()

# %%
sns.distplot(titanic_df['Age'])
# Out:
# /var/folders/26/w56ybb2s7tb9rmnhvsgnxtz80000gn/T/ipykernel_28845/134107046.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic_df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.boxplot(titanic_df.Age)
# Out:
# <Axes: ylabel='Age'>

# %%
bivariate /    multivariate - 
scatterplot -> num - num 
    - sns.scatterplot(,hue,style)
barplot - > num - cat
    - sns.barplot(data1,data2,hue)
boxplot - > num - cat
    - sns.boxplot(data1,data2,hue)
distplot (num - cat)
    - sns.distplot(data1,hist=False)
    - sns.distplot(data2,hist=False)
heatmap -> cat - cat
    - pd.crosstab(data,data)
    - sns.heatmap(crosstab_data)


clustermap - > cat - cat
    pd.crosstab(data1,data2)
    clustermap() - closeness between the values
    dendograms
pairplot - > collection of scatt
    numericals
    sns.pairplot(,hue = '')
lineplot - > num -  num (time series)
    sns.lineplot()

# %%
sns.boxplot(titanic_df.Fare)
# Out:
# <Axes: ylabel='Fare'>

# %%
'''
Scatterplot works with continous and continous
The ranges of the values should be similar
'''
sns.scatterplot([titanic_df.Age,titanic_df.Fare])
# Out:
# <Axes: >

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.barplot(data=titanic_df,x='Pclass',y='Fare')
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.boxplot([titanic_df.Age,titanic_df.Fare])
# Out:
# <Axes: >

# %%
# multivariate analysis
sns.barplot(data = titanic_df,x='Pclass',y='Fare',hue='Sex')
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.scatterplot(data=titanic_df[titanic_df['Fare']< 100],x='Age',y='Fare',hue='Pclass',style='Survived',)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
sns.heatmap(pd.crosstab(titanic_df.Pclass,titanic_df.Survived))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
sns.clustermap(pd.crosstab(titanic_df.Pclass,titanic_df.Survived))

# %%
Descriptive & General Questions
Who are the top 5 run-scorers in this dataset?

Which country has the most representation in this top batsman list?

Who has the longest career duration based on the 'Time Period' column?

What is the average number of matches played by the batsmen in this dataset?

Who has the highest individual score ('Highest Score')?

Who has the maximum number of 'Not Outs'?

Univariate Analysis (Distributions & Outliers)
What is the distribution of 'Batting Averages'? Is it normally distributed or skewed?

Are there any outliers in 'Strike Rate'? (e.g., players scoring exceptionally fast or slow).

How many players have scored zero 'Ducks'?

What is the frequency of 'Centuries' among the players? (e.g., How many have 0, 1, 2+ centuries?)

Which variable has the highest standard deviation: Runs, Balls Faced, or Strike Rate?

What is the spread of 'Sixes' hit by the players?

Bivariate Analysis (Relationships & Comparisons)
Runs vs. Matches: Is there a strong linear correlation between the number of matches played and total runs scored?

Strike Rate vs. Average: Do players with high strike rates tend to have lower batting averages?

Country vs. Performance: Which country has the highest average Batting Average across its players?

Boundaries vs. Runs: What is the relationship between the number of 'Fours' and Total 'Runs'?

Conversion Rate: Which player has the best conversion rate of Fifties to Centuries? (i.e., Who capitalizes most on a good start?)

Not Outs vs. Average: Does having a high number of 'Not Outs' significantly inflate a player's Batting Average?

Balls Faced vs. Sixes: Do players who face more balls hit significantly more sixes, or is it a trait of specific aggressive players?

Multivariate & Advanced Analysis
Boundary Contribution: What percentage of each player's total runs comes purely from boundaries (Fours + Sixes)?

Efficiency: Who has the best "Balls per Boundary" ratio?

Era Analysis: Do players who started their careers after 2000 have a higher average Strike Rate compared to those who started before?

Player Archetypes: Can we group players into categories like "Anchors" (High Average, Moderate SR) and "Finishers" (High Not Outs, High SR)?

Hard Hitting: Who has the highest ratio of Sixes to Fours?

Consistency: If we consider Matches Played vs. Ducks, who is the most consistent player (lowest Ducks per Match)?

Composite Score: If we rank players by (Batting Average × Strike Rate), who comes out on top?

Country Dominance: Is there a specific country that dominates the top quadrant of the "Runs vs. Strike Rate" scatter plot?

Longevity vs. Performance: Do players with longer careers (Time Period > 10 years) maintain a Batting Average above 40?

Scoring Intensity: Which player has the highest Runs per Match ratio?

Risk Taking: Is there a correlation between a high number of 'Sixes' and a high number of 'Ducks'?
